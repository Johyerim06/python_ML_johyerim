# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('PolynomialRegressionData.csv')
dataset.head()
# Out:
#    hour  score
# 0   0.2      2
# 1   0.5      4
# 2   0.8      6
# 3   0.9      4
# 4   1.2      6

# %%
X=dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression() #Linear 모델 만들어짐짐
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'b')
plt.plot(X, reg.predict(X), color = 'g')
plt.title("score of hours")
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
reg.score(X, y)
# Out:
# 0.8169296513411765

# %%
degrees = [2, 4, 6, 7, 8]
for deg_num in degrees:
    poly_reg = PolynomialFeatures(degree=deg_num)

# %%
from sklearn.preprocessing import  PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)

# %%
X_poly[:5] # degree = 2일때 3번째컬럼은 제곱한값임
# Out:
# array([[1.0000e+00, 2.0000e-01, 4.0000e-02, 8.0000e-03, 1.6000e-03],
#        [1.0000e+00, 5.0000e-01, 2.5000e-01, 1.2500e-01, 6.2500e-02],
#        [1.0000e+00, 8.0000e-01, 6.4000e-01, 5.1200e-01, 4.0960e-01],
#        [1.0000e+00, 9.0000e-01, 8.1000e-01, 7.2900e-01, 6.5610e-01],
#        [1.0000e+00, 1.2000e+00, 1.4400e+00, 1.7280e+00, 2.0736e+00]])

# %%
X[:5]
# Out:
# array([[0.2],
#        [0.5],
#        [0.8],
#        [0.9],
#        [1.2]])

# %%
poly_reg.get_feature_names_out() # 무슨값있는지 보임임
# Out:
# array(['1', 'x0', 'x0^2', 'x0^3', 'x0^4'], dtype=object)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'b')
plt.plot(X, lin_reg.predict(poly_reg.fit_transform(X)), color = 'r')
plt.title("score of hours")
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
X_range = np.arange(min(X), max(X), 0.01) #임의의 값만듦 빈곳에
X_range
# Out:
# C:\Users\koro2\AppData\Local\Temp\ipykernel_10520\3280458042.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_range = np.arange(min(X), max(X), 0.01) #임의의 값만듦 빈곳에
# array([0.2 , 0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 ,
#        0.31, 0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41,
#        0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52,
#        0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63,
#        0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74,
#        0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85,
#        0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96,
#        0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03, 1.04, 1.05, 1.06, 1.07,
# ...

# %%
X_range = X_range.reshape(len(X_range),1) #2차원배열로 설설정정
X_range
# Out:
# array([[0.2 ],
#        [0.21],
#        [0.22],
#        [0.23],
#        [0.24],
#        [0.25],
#        [0.26],
#        [0.27],
#        [0.28],
#        [0.29],
#        [0.3 ],
#        [0.31],
#        [0.32],
#        [0.33],
#        [0.34],
#        [0.35],
#        [0.36],
#        [0.37],
#        [0.38],
#        [0.39],
#        [0.4 ],
#        [0.41],
#        [0.42],
#        [0.43],
#        [0.44],
#        [0.45],
#        [0.46],
#        [0.47],
#        [0.48],
#        [0.49],
#        [0.5 ],
#        [0.51],
#        [0.52],
#        [0.53],
#        [0.54],
#        [0.55],
#        [0.56],
#        [0.57],
#        [0.58],
#        [0.59],
#        [0.6 ],
#        [0.61],
#        [0.62],
#        [0.63],
#        [0.64],
#        [0.65],
#        [0.66],
#        [0.67],
#        [0.68],
#        [0.69],
#        [0.7 ],
#        [0.71],
#        [0.72],
#        [0.73],
#        [0.74],
#        [0.75],
#        [0.76],
#        [0.77],
# ...

# %%
plt.scatter(X, y, color = 'b')
plt.plot(X_range, lin_reg.predict(poly_reg.fit_transform(X_range)), color = 'r')
plt.title("score of hours")
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

# %%
reg.predict([[2]])
# Out:
# array([19.85348988])

# %%
lin_reg.predict(poly_reg.fit_transform([[2]]))
# Out:
# array([8.70559135])

# %%
lin_reg.score(X_poly, y)
# Out:
# 0.9782775579000045

# %%
reg.score(X, y)
# Out:
# 0.8169296513411765
